# %%
import geopandas as gpd
from mongodb.content_provider import ContentProvider
from shapely.geometry import mapping
from pymongo.errors import OperationFailure
import re

# %%
data = gpd.read_file('./data/mars_mro_crism_trdr_ga/mars_mro_crism_trdr_ga.shp')
data
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../data/mars_mro_crism_trdr_ga/mars_mro_crism_trdr_ga.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 data = gpd.read_file('../data/mars_mro_crism_trdr_ga/mars_mro_crism_trdr_ga.shp')
#       2 data
#
# File ~/mongo_test/lib/python3.8/site-packages/geopandas-0.10.2-py3.8.egg/geopandas/io/file.py:201, in _read_file(filename, bbox, mask, rows, **kwargs)
#     198     reader = fiona.open
#     200 with fiona_env():
# --> 201     with reader(path_or_bytes, **kwargs) as features:
#     202
#     203         # In a future Fiona release the crs attribute of features will
#     204         # no longer be a dict, but will behave like a dict. So this should
#     205         # be forwards compatible
#     206         crs = (
#     207             features.crs["init"]
#     208             if features.crs and "init" in features.crs
#     209             else features.crs_wkt
#     210         )
#     212         # handle loading the bounding box
#
# File ~/mongo_test/lib/python3.8/site-packages/Fiona-1.8.21-py3.8-linux-x86_64.egg/fiona/env.py:408, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwargs)
#     405 @wraps(f)
#     406 def wrapper(*args, **kwargs):
#     407     if local._env:
# --> 408         return f(*args, **kwargs)
#     409     else:
#     410         if isinstance(args[0], str):
#
# File ~/mongo_test/lib/python3.8/site-packages/Fiona-1.8.21-py3.8-linux-x86_64.egg/fiona/__init__.py:264, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     261     path = parse_path(fp)
#     263 if mode in ('a', 'r'):
# --> 264     c = Collection(path, mode, driver=driver, encoding=encoding,
#     265                    layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     266 elif mode == 'w':
#     267     if schema:
#     268         # Make an ordered dict of schema properties.
#
# File ~/mongo_test/lib/python3.8/site-packages/Fiona-1.8.21-py3.8-linux-x86_64.egg/fiona/collection.py:162, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160 if self.mode == 'r':
#     161     self.session = Session()
# --> 162     self.session.start(self, **kwargs)
#     163 elif self.mode in ('a', 'w'):
#     164     self.session = WritingSession()
#
# File fiona/ogrext.pyx:540, in fiona.ogrext.Session.start()
#
# File fiona/_shim.pyx:90, in fiona._shim.gdal_open_vector()
#
# DriverError: ../data/mars_mro_crism_trdr_ga/mars_mro_crism_trdr_ga.shp: No such file or directory

# %%
data["_id"] = 'mars_mro_ctx_edr_c0a_' + data.index.astype(str)
data
# Out:
#         CenterLat  CenterLon   MaxLat   MinLat  EastLon  WestLon  EmAngle  \
# 0        -18.7703   309.1869 -14.5942 -22.5792   313.48   304.74     0.18
# 1        -45.7685   303.7626 -31.8957 -59.0826   307.98   296.89     0.13
# 2        -44.3874   164.5286 -44.1119 -44.6718   164.87   164.19     0.08
# 3          6.6369   157.9248   7.1262   6.1476   158.21   157.64     0.08
# 4         78.2866   140.3969  78.5188  78.0537   141.26   139.50     0.09
# ...           ...        ...      ...      ...      ...      ...      ...
# 129205    44.0431   177.3312  46.5023  41.5839   178.03   176.56     0.09
# 129206    74.3861   168.9478  74.7694  74.0017   169.88   167.97     0.79
# 129207   -25.1987   131.4342 -24.8113 -25.5855   131.72   131.15     0.09
# 129208    19.3675   127.5444  19.7538  18.9810   127.86   127.23    17.71
# 129209    31.3787    97.2140  31.7664  30.9906    97.54    96.88     0.25
#
#         InAngle  PhAngle  SolLong  ...  \
# 0         71.52    71.59    29.39  ...
# 1         83.06    83.12    29.39  ...
# 2         84.00    83.93   112.76  ...
# 3         52.17    52.13   112.76  ...
# 4         58.21    58.26   112.77  ...
# ...         ...      ...      ...  ...
# 129205    46.39    46.38    92.98  ...
# 129206    54.88    54.22    92.99  ...
# 129207    74.16    74.09    93.05  ...
# 129208    51.37    35.55    93.05  ...
# 129209    47.04    46.80    93.08  ...
#
#                                                   Ext2URL Ext3URL  \
# 0       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 1       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 2       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 3       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 4       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# ...                                                   ...     ...
# 129205  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129206  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129207  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129208  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129209  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
#
#                                                   ProdURL  \
# 0       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 1       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 2       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 3       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 4       https://ode.rsl.wustl.edu/mars/indexproductpag...
# ...                                                   ...
# 129205  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129206  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129207  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129208  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129209  https://ode.rsl.wustl.edu/mars/indexproductpag...
#
#                                                  FilesURL  \
# 0       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 1       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 2       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 3       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 4       https://ode.rsl.wustl.edu/mars/productfiles.as...
# ...                                                   ...
# 129205  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129206  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129207  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129208  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129209  https://ode.rsl.wustl.edu/mars/productfiles.as...
#
#                                                  LabelURL  \
# 0       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 1       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 2       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 3       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 4       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# ...                                                   ...
# 129205  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129206  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129207  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129208  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129209  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
#
#                                                  PILOTURL     ODEId  \
# 0       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9028115
# 1       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9028125
# 2       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029755
# 3       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029768
# 4       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029777
# ...                                                   ...       ...
# 129205  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953973
# 129206  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953979
# 129207  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953982
# 129208  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953985
# 129209  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953988
#
#        SubSiteTag                                           geometry  \
# 0            None  POLYGON ((-55.26000 -21.68670, -53.84000 -14.5...
# 1            None  POLYGON ((-63.11000 -58.78100, -57.16000 -31.8...
# 2            None  POLYGON ((164.78000 -44.11190, 164.87000 -44.6...
# 3            None  POLYGON ((158.10000 7.12620, 158.21000 6.19700...
# 4            None  POLYGON ((140.82000 78.51880, 141.26000 78.124...
# ...           ...                                                ...
# 129205       None  POLYGON ((177.30000 46.50230, 178.03000 41.643...
# 129206       None  POLYGON ((169.47000 74.76940, 169.88000 74.072...
# 129207       None  POLYGON ((131.62000 -24.81130, 131.72000 -25.5...
# 129208       None  POLYGON ((127.78000 19.75380, 127.86000 19.040...
# 129209       None  POLYGON ((97.45000 31.76640, 97.54000 31.05030...
#
#                                 _id
# 0            mars_mro_ctx_edr_c0a_0
# 1            mars_mro_ctx_edr_c0a_1
# 2            mars_mro_ctx_edr_c0a_2
# 3            mars_mro_ctx_edr_c0a_3
# 4            mars_mro_ctx_edr_c0a_4
# ...                             ...
# 129205  mars_mro_ctx_edr_c0a_129205
# 129206  mars_mro_ctx_edr_c0a_129206
# 129207  mars_mro_ctx_edr_c0a_129207
# 129208  mars_mro_ctx_edr_c0a_129208
# 129209  mars_mro_ctx_edr_c0a_129209
#
# [129210 rows x 34 columns]

# %%
cols = data.columns.tolist()
cols = cols[-1:] + cols[:-1]
data = data[cols]
data
# Out:
#                                 _id  CenterLat  CenterLon   MaxLat   MinLat  \
# 0            mars_mro_ctx_edr_c0a_0   -18.7703   309.1869 -14.5942 -22.5792
# 1            mars_mro_ctx_edr_c0a_1   -45.7685   303.7626 -31.8957 -59.0826
# 2            mars_mro_ctx_edr_c0a_2   -44.3874   164.5286 -44.1119 -44.6718
# 3            mars_mro_ctx_edr_c0a_3     6.6369   157.9248   7.1262   6.1476
# 4            mars_mro_ctx_edr_c0a_4    78.2866   140.3969  78.5188  78.0537
# ...                             ...        ...        ...      ...      ...
# 129205  mars_mro_ctx_edr_c0a_129205    44.0431   177.3312  46.5023  41.5839
# 129206  mars_mro_ctx_edr_c0a_129206    74.3861   168.9478  74.7694  74.0017
# 129207  mars_mro_ctx_edr_c0a_129207   -25.1987   131.4342 -24.8113 -25.5855
# 129208  mars_mro_ctx_edr_c0a_129208    19.3675   127.5444  19.7538  18.9810
# 129209  mars_mro_ctx_edr_c0a_129209    31.3787    97.2140  31.7664  30.9906
#
#         EastLon  WestLon  EmAngle  InAngle  PhAngle  ...  \
# 0        313.48   304.74     0.18    71.52    71.59  ...
# 1        307.98   296.89     0.13    83.06    83.12  ...
# 2        164.87   164.19     0.08    84.00    83.93  ...
# 3        158.21   157.64     0.08    52.17    52.13  ...
# 4        141.26   139.50     0.09    58.21    58.26  ...
# ...         ...      ...      ...      ...      ...  ...
# 129205   178.03   176.56     0.09    46.39    46.38  ...
# 129206   169.88   167.97     0.79    54.88    54.22  ...
# 129207   131.72   131.15     0.09    74.16    74.09  ...
# 129208   127.86   127.23    17.71    51.37    35.55  ...
# 129209    97.54    96.88     0.25    47.04    46.80  ...
#
#                                                    ExtURL  \
# 0       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 1       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 2       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 3       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 4       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# ...                                                   ...
# 129205  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129206  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129207  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129208  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129209  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
#
#                                                   Ext2URL Ext3URL  \
# 0       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 1       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 2       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 3       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 4       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# ...                                                   ...     ...
# 129205  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129206  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129207  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129208  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129209  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
#
#                                                   ProdURL  \
# 0       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 1       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 2       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 3       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 4       https://ode.rsl.wustl.edu/mars/indexproductpag...
# ...                                                   ...
# 129205  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129206  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129207  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129208  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129209  https://ode.rsl.wustl.edu/mars/indexproductpag...
#
#                                                  FilesURL  \
# 0       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 1       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 2       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 3       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 4       https://ode.rsl.wustl.edu/mars/productfiles.as...
# ...                                                   ...
# 129205  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129206  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129207  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129208  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129209  https://ode.rsl.wustl.edu/mars/productfiles.as...
#
#                                                  LabelURL  \
# 0       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 1       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 2       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 3       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 4       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# ...                                                   ...
# 129205  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129206  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129207  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129208  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129209  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
#
#                                                  PILOTURL     ODEId  \
# 0       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9028115
# 1       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9028125
# 2       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029755
# 3       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029768
# 4       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029777
# ...                                                   ...       ...
# 129205  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953973
# 129206  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953979
# 129207  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953982
# 129208  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953985
# 129209  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953988
#
#        SubSiteTag                                           geometry
# 0            None  POLYGON ((-55.26000 -21.68670, -53.84000 -14.5...
# 1            None  POLYGON ((-63.11000 -58.78100, -57.16000 -31.8...
# 2            None  POLYGON ((164.78000 -44.11190, 164.87000 -44.6...
# 3            None  POLYGON ((158.10000 7.12620, 158.21000 6.19700...
# 4            None  POLYGON ((140.82000 78.51880, 141.26000 78.124...
# ...           ...                                                ...
# 129205       None  POLYGON ((177.30000 46.50230, 178.03000 41.643...
# 129206       None  POLYGON ((169.47000 74.76940, 169.88000 74.072...
# 129207       None  POLYGON ((131.62000 -24.81130, 131.72000 -25.5...
# 129208       None  POLYGON ((127.78000 19.75380, 127.86000 19.040...
# 129209       None  POLYGON ((97.45000 31.76640, 97.54000 31.05030...
#
# [129210 rows x 34 columns]

# %%
data.loc[[163],'geometry'].plot(figsize=(1, 100))
# Out:
# <AxesSubplot:>

# %%
data['geometry'] = data['geometry'].apply(lambda x:mapping(x))
data
# Out:
# /home/canyetismis/mongo_test/lib/python3.8/site-packages/geopandas-0.10.2-py3.8.egg/geopandas/geodataframe.py:1350: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
#                                 _id  CenterLat  CenterLon   MaxLat   MinLat  \
# 0            mars_mro_ctx_edr_c0a_0   -18.7703   309.1869 -14.5942 -22.5792
# 1            mars_mro_ctx_edr_c0a_1   -45.7685   303.7626 -31.8957 -59.0826
# 2            mars_mro_ctx_edr_c0a_2   -44.3874   164.5286 -44.1119 -44.6718
# 3            mars_mro_ctx_edr_c0a_3     6.6369   157.9248   7.1262   6.1476
# 4            mars_mro_ctx_edr_c0a_4    78.2866   140.3969  78.5188  78.0537
# ...                             ...        ...        ...      ...      ...
# 129205  mars_mro_ctx_edr_c0a_129205    44.0431   177.3312  46.5023  41.5839
# 129206  mars_mro_ctx_edr_c0a_129206    74.3861   168.9478  74.7694  74.0017
# 129207  mars_mro_ctx_edr_c0a_129207   -25.1987   131.4342 -24.8113 -25.5855
# 129208  mars_mro_ctx_edr_c0a_129208    19.3675   127.5444  19.7538  18.9810
# 129209  mars_mro_ctx_edr_c0a_129209    31.3787    97.2140  31.7664  30.9906
#
#         EastLon  WestLon  EmAngle  InAngle  PhAngle  ...  \
# 0        313.48   304.74     0.18    71.52    71.59  ...
# 1        307.98   296.89     0.13    83.06    83.12  ...
# 2        164.87   164.19     0.08    84.00    83.93  ...
# 3        158.21   157.64     0.08    52.17    52.13  ...
# 4        141.26   139.50     0.09    58.21    58.26  ...
# ...         ...      ...      ...      ...      ...  ...
# 129205   178.03   176.56     0.09    46.39    46.38  ...
# 129206   169.88   167.97     0.79    54.88    54.22  ...
# 129207   131.72   131.15     0.09    74.16    74.09  ...
# 129208   127.86   127.23    17.71    51.37    35.55  ...
# 129209    97.54    96.88     0.25    47.04    46.80  ...
#
#                                                    ExtURL  \
# 0       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 1       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 2       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 3       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 4       https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# ...                                                   ...
# 129205  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129206  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129207  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129208  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
# 129209  https://pds-imaging.jpl.nasa.gov/pds/prod?q=OF...
#
#                                                   Ext2URL Ext3URL  \
# 0       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 1       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 2       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 3       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 4       http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# ...                                                   ...     ...
# 129205  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129206  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129207  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129208  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
# 129209  http://viewer.mars.asu.edu/planetview/inst/ctx...    None
#
#                                                   ProdURL  \
# 0       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 1       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 2       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 3       https://ode.rsl.wustl.edu/mars/indexproductpag...
# 4       https://ode.rsl.wustl.edu/mars/indexproductpag...
# ...                                                   ...
# 129205  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129206  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129207  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129208  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 129209  https://ode.rsl.wustl.edu/mars/indexproductpag...
#
#                                                  FilesURL  \
# 0       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 1       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 2       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 3       https://ode.rsl.wustl.edu/mars/productfiles.as...
# 4       https://ode.rsl.wustl.edu/mars/productfiles.as...
# ...                                                   ...
# 129205  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129206  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129207  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129208  https://ode.rsl.wustl.edu/mars/productfiles.as...
# 129209  https://ode.rsl.wustl.edu/mars/productfiles.as...
#
#                                                  LabelURL  \
# 0       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 1       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 2       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 3       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 4       https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# ...                                                   ...
# 129205  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129206  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129207  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129208  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
# 129209  https://pds-imaging.jpl.nasa.gov/data/mro/mars...
#
#                                                  PILOTURL     ODEId  \
# 0       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9028115
# 1       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9028125
# 2       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029755
# 3       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029768
# 4       https://pilot.wr.usgs.gov/?view=map&upcSearchI...   9029777
# ...                                                   ...       ...
# 129205  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953973
# 129206  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953979
# 129207  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953982
# 129208  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953985
# 129209  https://pilot.wr.usgs.gov/?view=map&upcSearchI...  32953988
#
#        SubSiteTag                                           geometry
# 0            None  {'type': 'Polygon', 'coordinates': (((-55.26, ...
# 1            None  {'type': 'Polygon', 'coordinates': (((-63.11, ...
# 2            None  {'type': 'Polygon', 'coordinates': (((164.78, ...
# 3            None  {'type': 'Polygon', 'coordinates': (((158.1, 7...
# 4            None  {'type': 'Polygon', 'coordinates': (((140.82, ...
# ...           ...                                                ...
# 129205       None  {'type': 'Polygon', 'coordinates': (((177.3, 4...
# 129206       None  {'type': 'Polygon', 'coordinates': (((169.47, ...
# 129207       None  {'type': 'Polygon', 'coordinates': (((131.62, ...
# 129208       None  {'type': 'Polygon', 'coordinates': (((127.78, ...
# 129209       None  {'type': 'Polygon', 'coordinates': (((97.45, 3...
#
# [129210 rows x 34 columns]

# %%
data["geometry"].iloc[1]
# Out:
# {'type': 'Polygon',
#  'coordinates': (((-63.11, -58.781),
#    (-57.16, -31.8957),
#    (-52.02, -32.5027),
#    (-59.17, -59.0826),
#    (-63.11, -58.781)),)}

# %%
contentProvider = ContentProvider("mongo_test", "geodata")
contentProvider.delete_data()
contentProvider.insert_data(data)

# %%
#contentProvider.create_2dsphere_index("geometry")

# %%
broken_values = []
def index_locator():
    try:
        contentProvider.create_2dsphere_index("geometry")
    except OperationFailure as e:
        index = re.search('_id: "(.*)"', str(e))
        index = index.group(1).split('"',1)
        broken_values.append(index[0])
        print(index[0])
        broken_value ={"_id" : index[0]}
        contentProvider.delete_data(broken_value)
        index_locator()

index_locator()
# Out:
# []
# mars_mro_ctx_edr_c0a_163
# mars_mro_ctx_edr_c0a_164
# mars_mro_ctx_edr_c0a_4459
# mars_mro_ctx_edr_c0a_4461
# mars_mro_ctx_edr_c0a_82097
# mars_mro_ctx_edr_c0a_86217
# mars_mro_ctx_edr_c0a_86627
# mars_mro_ctx_edr_c0a_106117

# %%
prit(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 prit(a)
#
# NameError: name 'prit' is not defined
