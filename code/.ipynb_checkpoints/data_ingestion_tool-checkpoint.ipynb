# %%
import geopandas as gpd
from mongodb.content_provider import ContentProvider

# %%
data = gpd.read_file('../data/mars_mro_ctx_edr_c0a/mars_mro_ctx_edr_c0a.shp')
data
# Out:
#         CenterLat  CenterLon   MaxLat   MinLat  EastLon  WestLon  EmAngle  \
# 0        -18.7703   309.1869 -14.5942 -22.5792   313.48   304.74     0.18
# 1        -45.7685   303.7626 -31.8957 -59.0826   307.98   296.89     0.13
# 2        -44.3874   164.5286 -44.1119 -44.6718   164.87   164.19     0.08
# 3          6.6369   157.9248   7.1262   6.1476   158.21   157.64     0.08
# 4         78.2866   140.3969  78.5188  78.0537   141.26   139.50     0.09
# ...           ...        ...      ...      ...      ...      ...      ...
# 129205    44.0431   177.3312  46.5023  41.5839   178.03   176.56     0.09
# 129206    74.3861   168.9478  74.7694  74.0017   169.88   167.97     0.79
# 129207   -25.1987   131.4342 -24.8113 -25.5855   131.72   131.15     0.09
# 129208    19.3675   127.5444  19.7538  18.9810   127.86   127.23    17.71
# 129209    31.3787    97.2140  31.7664  30.9906    97.54    96.88     0.25
#
#         InAngle  PhAngle  SolLong  ...  \
# ...

# %%
for index, row in data.iterrows():
    row["_id"] = "mars_mro_ctx_edr_c0a_" + str(index + 1)
data
# Out:
# /tmp/ipykernel_5965/222538072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["_id"].iloc[index] = "mars_mro_ctx_edr_c0a_" + str(index + 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
#       1 for index, row in data.iterrows():
# ----> 2     data["_id"].iloc[index] = "mars_mro_ctx_edr_c0a_" + str(index + 1)
#       3 data
#
# File ~/mongo_test/lib/python3.8/site-packages/pandas-1.4.1-py3.8-linux-x86_64.egg/pandas/core/indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# ...
